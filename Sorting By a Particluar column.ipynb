# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train=pd.read_excel("C:/Users/user/Desktop/Marks Excel/CHN-210.xlsx")

# %%
train=train.drop([0,1],axis=0)

# %%
train=train.drop([2],axis=0)

# %%
train
# Out:
#    Subject List of CHN-210 - INDUSTRIAL INSTRUMENTATION (2) Unnamed: 1  \
# 3                                                   1         18310001
# 4                                                   2         18112001
# 5                                                   3         18410004
# 6                                                   4         18118005
# 7                                                   5         18121003
# ..                                                ...              ...
# 89                                                 87         18118083
# 90                                                 88         18112087
# 91                                                 89         18112088
# 92                                                 90         18112089
# 93                                                 91         18112090
#
#                 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# ...

# %%
x=train.iloc[:,1:2].values

# %%
x
# Out:
# array([[18310001],
#        [18112001],
#        [18410004],
#        [18118005],
#        [18121003],
#        [18112002],
#        [18112003],
#        [18112004],
#        [18112005],
#        [18112006],
#        [18112007],
#        [18112008],
#        [18112010],
#        [18112011],
#        [18112012],
#        [18112013],
#        [18112014],
#        [18112015],
#        [18112016],
#        [18118018],
#        [18112018],
#        [18112019],
#        [18112020],
#        [18112021],
#        [18112022],
#        [18112023],
#        [18112024],
#        [18112025],
#        [18112026],
#        [18112027],
#        [18112028],
#        [18112029],
#        [18112030],
#        [18112031],
#        [18112032],
#        [18112033],
#        [18112034],
#        [18112035],
#        [18112036],
#        [18112037],
#        [18112038],
#        [18112042],
#        [18112043],
#        [18112044],
#        [18112045],
#        [18112046],
#        [18112047],
# ...

# %%
x2=train.iloc[:,9:10].values

# %%
x2
# Out:
# array([[8.544],
#        [6.603],
#        [8.75],
#        [8.706],
#        [8.132],
#        [7.088],
#        [7.265],
#        [7.735],
#        [7.721],
#        [6.471],
#        [5.162],
#        [7.838],
#        [6.309],
#        [6.044],
#        [7.118],
#        [7.971],
#        [7.941],
#        [7.706],
#        [9.088],
#        [9.471],
#        [6.971],
#        [9.397],
#        [8.529],
#        [7.603],
#        [5.103],
#        [5.985],
#        [4.794],
#        [7.706],
#        [6.882],
#        [7.5],
#        [7.691],
#        [8.368],
#        [8.147],
#        [7.926],
#        [8.5],
#        [8.706],
#        [5.735],
#        [8.132],
#        [7.397],
#        [6.765],
#        [6.632],
#        [8.882],
#        [6.235],
#        [9.162],
#        [7.353],
#        [7.588],
#        [7.956],
#        [5.618],
#        [7.647],
#        [8.926],
#        [7.618],
#        [7.676],
#        [5.088],
#        [7.147],
#        [7.162],
# ...

# %%
df=pd.DataFrame({'Enr':[x]
                'Cg':[trai]})
# Out:
#   File "<ipython-input-57-381821993b6e>", line 2
#     'Cg':[x2]})
#        ^
# SyntaxError: invalid syntax

# %%
x3=train[['Unnamed: 1','Unnamed: 2','Unnamed: 9']]

# %%
x3
# Out:
#    Unnamed: 1              Unnamed: 2 Unnamed: 9
# 3    18310001       AADITYA GOVERDHAN      8.544
# 4    18112001           ABHISHEK NAIN      6.603
# 5    18410004         ABHYUDAY MISHRA       8.75
# 6    18118005        ADITYA BHATNAGAR      8.706
# 7    18121003           ADRIJ SHIKHAR      8.132
# ..        ...                     ...        ...
# 89   18118083  VINAY RAJENDRA AGARWAL      8.176
# 90   18112087            VISHAL NAGAR      6.618
# 91   18112088            VIVEK GAUTAM      5.221
# 92   18112089        VIVEKANAND VERMA      7.588
# 93   18112090            YASH AGRAWAL       8.75
#
# [91 rows x 3 columns]

# %%
x3.sort_values(["Unnamed: 9"], 
                 ascending=True, inplace=True)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
x3
# Out:
#    Unnamed: 1           Unnamed: 2 Unnamed: 9
# 29   18112024          HARSH KUMAR      4.794
# 77   18112077  SOLANKI MAYANKKUMAR      4.941
# 55   18112054        PRANJAL MEENA      5.088
# 27   18112022               GAURAV      5.103
# 70   18112070  RUSHIKESH TELHARKAR      5.147
# ..        ...                  ...        ...
# 21   18112016          ARNAV CHAND      9.088
# 46   18112044         NARPAT SINGH      9.162
# 81   18118074       SWAPNIL VATSAL      9.176
# 24   18112019      DEVASHISH YADAV      9.397
# 22   18118018          AYUSH SINGH      9.471
#
# [91 rows x 3 columns]

# %%
x3.to_csv("C:/Users/user/Desktop/Marks Excel/CHN-210_sorted.csv")
